# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/ximen20260316/blob/main/ximen20260325.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# list[key]
scores = [80, 60, 70, 50]

count = 0
i = 0
while i < len(scores):
    s = scores[i]
    if s >= 60:
        count = count + 1
    i = i + 1
print(count)
# Out:
# 3

# %%
# 上面這個寫法的侷限性:
# 以後會遇到某些群集 key不是0 1 2 3 scores[i]就無法用
# 如果迴圈: 是走過群集 for in (走過) 群集(list/str)
# 保證群集裡的每個東西都會拿出來給你一遍
# 對於有序(key=0 1 2 3) 就會照順序給你
scores = [80, 60, 70, 50]

count = 0
for s in scores:
    if s >= 60:
        count = count + 1
print(count)
# Out:
# 0

# %%
# 目前累加的總和
total = 0
i = 0
while i < 10:
    total = total + (i + 1)
    print(total)
    i = i + 1

# %%
total = 0
for i in [0, 1, 2, 3, 4]:
    total = total + (i + 1)
    print(total)

# range(5) -> [0, 1, 2, 3, 4] (o)
# range(2, 5) -> [2, 3, 4]
# range(1, 7, 2) -> [1, 3, 5]
total = 0
for i in range(5):
    total = total + (i + 1)
    print(total)
# Out:
# 1
# 3
# 6
# 10
# 15
# 1
# 3
# 6
# 10
# 15

# %%
# https://zh.wikipedia.org/zh-tw/E_(%E6%95%B0%E5%AD%A6%E5%B8%B8%E6%95%B0)
# 1 / 0! + 1 / 1! + 1 / 2!
total = 0
frac = 1

i = 0
while i < 100:
    # 0! 1! 2! 3!
    if not i == 0:
        frac = frac * i
    total = total + (1 / frac)
    i = i + 1
print(total)
# Out:
# 2.7182818284590455

# %%
total = 0
frac = 1

for i in range(10):
    # 0! 1! 2! 3!
    if not i == 0:
        frac = frac * i
    total = total + (1 / frac)

print(total)
# Out:
# 0 1
# 1 1
# 2 2
# 3 6
# 4 24
# 5 120
# 6 720
# 7 5040
# 8 40320
# 9 362880
# 2.7182815255731922

# %%
# 命令(非python語法): 記得!加在前面
# 安裝函式庫: pip install 函式庫名字
# !pip install ColabTurtle

# %%
# as: 右邊=
import math
import ColabTurtle.Turtle as turtle

turtle.initializeTurtle(initial_speed=10, initial_window_size=(800,500))
# 幾邊形
many = 100
init_l = 100
angle = (360 / many) / 2
angle_rad = math.radians(angle)
l = 2 * init_l * math.sin(angle_rad)

turtle.penup()
turtle.forward(init_l)
turtle.right(90+angle)

turtle.pendown()
i = 0
while i < many:
    turtle.forward(l)
    turtle.right(2 * angle)
    i = i + 1
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %% [markdown]
# ![未命名.png](data:image/png;base64,...)

# %%
import ColabTurtle.Turtle as turtle

turtle.initializeTurtle(initial_speed=1, initial_window_size=(800,500))

# 拿到位置: turtle.pos()
x, y = turtle.pos()
oldx, oldy = x, y

turtle.forward(100)

turtle.goto(x, y)
turtle.goto(0, 0)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="150.0" x2="400" y2="250" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400" y1="250" x2="0" y2="0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,0,0) translate(-18, -18)">
# ...
