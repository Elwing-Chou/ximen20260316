# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/ximen20260316/blob/main/ximen20260401.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# WIN: -headers "Origin: https://ani.gamer.com.tw" -i "" anime.mp4
#
# MAC: -headers 'Origin: https://ani.gamer.com.tw' -i '' anime.mp4
#
# cd xxx 可執行的程式 參數
#
# 位置參數(放最後面, 一定會帶入的)
# 告訴她參數拿來幹嗎 a. 短參數: -V -短參數名 值 b. 長參數: --version --長參數名 值

# %%
import urllib.request as req

url = "https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=36632&geo=TW%2CHK"
req.urlopen(url)

# %%
f = open("a.txt", "w", encoding="utf-8")
# 寫入: write(f, "xyz")
# 專屬功能: f.write("xyz")
# 打不出來的字: \(逃脫字元)n  \t:TAB
f.write("xyz\n")
f.write("def")
# 關閉: close(f)
f.close()

# %%
f = open("a.txt", "r", encoding="utf-8")
# content = read(f)
content = f.read()
print(content)
f.close()
# Out:
# xyz
# def
